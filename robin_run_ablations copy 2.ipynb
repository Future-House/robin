# %% [markdown]
# # Robin

# %%
import logging

from robin.assays import experimental_assay
from robin.candidates import therapeutic_candidates
from robin.configuration_CROW_ablation import RobinConfiguration

# %% [markdown]
# ## Robin Set Up

# %%
config = RobinConfiguration(disease_name="dry age-related macular degeneration", num_candidates=55, num_assays=15,num_queries=10, use_direct_llm_for_crow=False, use_direct_llm_for_falcon=True, service_uri="https://api.platform.edisonscientific.com")

logger = logging.getLogger("robin")
logger.setLevel(logging.INFO)

# %% [markdown]
# # Initial therapeutics hypothesis generation

# %% [markdown]
# ### Experimental assay generation

# %%
candidate_generation_goal = await experimental_assay(configuration=config)
# Out:
# 2025-11-07 14:55:20,909 - robin.assays - INFO - Starting selection of a relevant experimental assay.
# 2025-11-07 14:55:20,910 - robin.assays - INFO - ————————————————————————————————————————————————————
# 2025-11-07 14:55:20,910 - robin.assays - INFO -
# Step 1: Formulating relevant queries for literature search...
# 2025-11-07 14:55:40,976 - robin.assays - INFO - Generated Queries:
# 2025-11-07 14:55:40,977 - robin.assays - INFO - 1. Search the literature for the key molecular pathways driving retinal pigment epithelium (RPE) cell dysfunction and atrophy in dry age-related macular degeneration, including complement activation, inflammasome signaling, lipid accumulation, oxidative damage, and downstream pro-apoptotic factors, with emphasis on identifying specific molecular targets amenable to small molecule modulation in cell culture systems
# 2025-11-07 14:55:40,978 - robin.assays - INFO - 2. Investigate comprehensive mechanistic studies on the role of local complement system dysregulation in the subretinal space during dry AMD pathogenesis, detailing complement factor expression in RPE, drusen biogenesis, MAC pore formation, and potential in vitro assays to quantify complement deposition, cell lysis, and cytokine release in RPE monolayer cultures
# 2025-11-07 14:55:40,979 - robin.assays - INFO - 3. Compile mechanistic evidence on impaired autophagy and mitophagy pathways in RPE cells under chronic oxidative stress conditions; include details on key regulators like mTORC1, AMPK, PINK1/Parkin, LC3-II lipidation, and protocols for fluorescence-based autophagic flux assays in RPE cell culture models
# 2025-11-07 14:55:40,979 - robin.assays - INFO - 4. Evaluate the biochemical basis of oxidative stress-induced damage in RPE cells in dry AMD, focusing on sources of reactive oxygen species, mitochondrial dysfunction, antioxidant defense mechanisms, and in vitro assays measuring ROS generation, mitochondrial membrane potential, and lipid peroxidation in relevant cell culture models
# 2025-11-07 14:55:40,980 - robin.assays - INFO - 5. Review studies on cholesterol and neutral lipid handling in RPE cells and drusen formation in dry AMD, including roles of apolipoproteins, ABCA1 transporter, and lipid peroxidation products, and outline cell-based assays to quantify intracellular lipid accumulation, foam cell formation, and lipofuscin deposition
# 2025-11-07 14:55:40,981 - robin.assays - INFO - 6. Survey mechanistic insights into chronic sterile inflammation in dry AMD, mapping the crosstalk between RPE cells and innate immune cells, cytokine profiles such as IL-1β, IL-18, TNFα, microglial activation, and develop cell co-culture or conditioned media assays to study inflammatory mediator release and RPE barrier disruption
# 2025-11-07 14:55:40,981 - robin.assays - INFO - 7. Identify cellular and molecular determinants of RPE tight junction integrity loss in dry AMD, highlighting Zo-1, occludin, claudins, and signaling pathways like Wnt/β-catenin and TGF-β, and establish assays to measure transepithelial resistance and permeability changes in RPE monolayers
# 2025-11-07 14:55:40,981 - robin.assays - INFO - 8. Research the mechanisms of photoreceptor outer segment phagocytosis by RPE cells in healthy and AMD contexts, focusing on MerTK, integrin signaling, opsonins, and lysosomal degradation, and propose quantitative in vitro assays using fluorescently labeled rod outer segments to assess RPE phagocytic capacity under stress conditions
# 2025-11-07 14:55:40,982 - robin.assays - INFO - 9. Explore high-content imaging and phenotypic screening platforms tailored for RPE cell models, summarizing fluorescent reporters, automated image analysis pipelines, multiplexed readouts for cell morphology, organelle health, cell death, and mitochondrial dynamics to enable mechanistic drug evaluations in dry AMD assays
# 2025-11-07 14:55:40,982 - robin.assays - INFO - 10. Assess the current state of induced pluripotent stem cell-derived RPE models for dry age-related macular degeneration research, detailing standard differentiation protocols, disease-relevant genetic backgrounds, functional characterization assays, and challenges in reproducibility and scalability for high-throughput drug screening
# 2025-11-07 14:55:40,983 - robin.assays - INFO -
# Step 2: Conducting literature search with CROW platform agent...
# 2025-11-07 14:55:41,815 - robin.utils - INFO - Starting literature search for 10 queries using job-futurehouse-paperqa2.
# 2025-11-07 15:09:31,301 - robin.utils - INFO - Finished processing 10 tasks.
# 2025-11-07 15:09:31,303 - robin.utils - INFO - Successfully wrote: query_1_search.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_1_search.txt
# 2025-11-07 15:09:31,304 - robin.utils - INFO - Successfully wrote: query_2_investigate.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_2_investigate.txt
# 2025-11-07 15:09:31,305 - robin.utils - INFO - Successfully wrote: query_3_compile.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_3_compile.txt
# 2025-11-07 15:09:31,306 - robin.utils - INFO - Successfully wrote: query_4_evaluate.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_4_evaluate.txt
# 2025-11-07 15:09:31,307 - robin.utils - INFO - Successfully wrote: query_5_review.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_5_review.txt
# 2025-11-07 15:09:31,307 - robin.utils - INFO - Successfully wrote: query_6_survey.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_6_survey.txt
# 2025-11-07 15:09:31,308 - robin.utils - INFO - Successfully wrote: query_7_identify.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_7_identify.txt
# 2025-11-07 15:09:31,309 - robin.utils - INFO - Successfully wrote: query_8_research.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_8_research.txt
# 2025-11-07 15:09:31,309 - robin.utils - INFO - Successfully wrote: query_9_explore.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_9_explore.txt
# 2025-11-07 15:09:31,310 - robin.utils - INFO - Successfully wrote: query_10_assess.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_literature_reviews/query_10_assess.txt
# 2025-11-07 15:09:31,310 - robin.assays - INFO -
# Step 3: Generating ideas for relevant experimental assays...
# 2025-11-07 15:10:05,877 - robin.assays - INFO - Strategy: Complement Deposition Imaging<|>Reasoning: Allows quantification of sub-lytic MAC (C5b-9) ...
# 2025-11-07 15:10:05,877 - robin.assays - INFO - Strategy: NLRP3 Inflammasome Activation Assay<|>Reasoning: Measures caspase-1 activity and IL-1β/IL-...
# 2025-11-07 15:10:05,877 - robin.assays - INFO - Strategy: Lipid Droplet Accumulation Assay<|>Reasoning: Uses BODIPY or Oil Red O staining to quantif...
# 2025-11-07 15:10:05,877 - robin.assays - INFO - Strategy: Oxidative Stress and Mitochondrial Potential Assay<|>Reasoning: Combines TMRM for Δψm and ...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Apoptotic Caspase Activity Assay<|>Reasoning: Quantifies caspase-3/7 activation in RPE via...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Autophagic Flux Tandem LC3 Reporter Assay<|>Reasoning: Employs mCherry-GFP-LC3 to distingu...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Cholesterol Efflux Functional Assay<|>Reasoning: Measures ABCA1-mediated efflux of radiola...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Cytokine Release Co-culture Assay<|>Reasoning: Applies conditioned media from stressed RPE...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Barrier Integrity TEER Assay<|>Reasoning: Monitors transepithelial electrical resistance a...
# 2025-11-07 15:10:05,878 - robin.assays - INFO - Strategy: Photoreceptor Outer Segment Phagocytosis Assay<|>Reasoning: Uses fluorescently labeled rod...
# 2025-11-07 15:10:05,879 - robin.assays - INFO - Strategy: High-Content Mitochondrial Morphofunction Assay<|>Reasoning: Integrates multiplexed live-c...
# 2025-11-07 15:10:05,879 - robin.assays - INFO - Strategy: CFH/CFI Complement Regulation Assay<|>Reasoning: Assesses RPE-secreted CFH/CFI activity by...
# 2025-11-07 15:10:05,879 - robin.assays - INFO - Strategy: Lysosomal Exocytosis Defense Assay<|>Reasoning: Quantifies β-hexosaminidase release from R...
# 2025-11-07 15:10:05,879 - robin.assays - INFO - Strategy: Mitophagy Reporter Assay<|>Reasoning: Employs mito-QC or PINK1/Parkin GFP translocation re...
# 2025-11-07 15:10:05,879 - robin.assays - INFO - Strategy: Lipofuscin Autofluorescence Assay<|>Reasoning: Measures intrinsic autofluorescence of accu...
# 2025-11-07 15:10:05,884 - robin.assays - INFO - Successfully exported to robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_summary.txt
# 2025-11-07 15:10:05,884 - robin.assays - INFO -
# Step 4: Detailed investigation and evaluation for each assay...
# 2025-11-07 15:10:05,885 - robin.assays - INFO - Using CROW platform agent for assay hypothesis reports...
# 2025-11-07 15:10:05,885 - robin.utils - INFO - Starting literature search for 15 queries using job-futurehouse-paperqa2.
# 2025-11-07 15:20:36,936 - robin.utils - INFO - Finished processing 15 tasks.
# 2025-11-07 15:20:36,938 - robin.utils - INFO - Successfully wrote: assay_hypothesis_1_complement.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_1_complement.txt
# 2025-11-07 15:20:36,939 - robin.utils - INFO - Successfully wrote: assay_hypothesis_2_nlrp3.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_2_nlrp3.txt
# 2025-11-07 15:20:36,939 - robin.utils - INFO - Successfully wrote: assay_hypothesis_3_lipid.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_3_lipid.txt
# 2025-11-07 15:20:36,940 - robin.utils - INFO - Successfully wrote: assay_hypothesis_4_oxidative.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_4_oxidative.txt
# 2025-11-07 15:20:36,941 - robin.utils - INFO - Successfully wrote: assay_hypothesis_5_apoptotic.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_5_apoptotic.txt
# 2025-11-07 15:20:36,941 - robin.utils - INFO - Successfully wrote: assay_hypothesis_6_autophagic.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_6_autophagic.txt
# 2025-11-07 15:20:36,942 - robin.utils - INFO - Successfully wrote: assay_hypothesis_7_cholesterol.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_7_cholesterol.txt
# 2025-11-07 15:20:36,942 - robin.utils - INFO - Successfully wrote: assay_hypothesis_8_cytokine.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_8_cytokine.txt
# 2025-11-07 15:20:36,943 - robin.utils - INFO - Successfully wrote: assay_hypothesis_9_barrier.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_9_barrier.txt
# 2025-11-07 15:20:36,943 - robin.utils - INFO - Successfully wrote: assay_hypothesis_10_photoreceptor.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_10_photoreceptor.txt
# 2025-11-07 15:20:36,944 - robin.utils - INFO - Successfully wrote: assay_hypothesis_11_high.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_11_high.txt
# 2025-11-07 15:20:36,944 - robin.utils - INFO - Successfully wrote: assay_hypothesis_12_cfh.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_12_cfh.txt
# 2025-11-07 15:20:36,945 - robin.utils - INFO - Successfully wrote: assay_hypothesis_13_lysosomal.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_13_lysosomal.txt
# 2025-11-07 15:20:36,945 - robin.utils - INFO - Successfully wrote: assay_hypothesis_14_mitophagy.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_14_mitophagy.txt
# 2025-11-07 15:20:36,946 - robin.utils - INFO - Successfully wrote: assay_hypothesis_15_lipofuscin.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_detailed_hypotheses/assay_hypothesis_15_lipofuscin.txt
# 2025-11-07 15:20:36,946 - robin.assays - INFO -
# Step 5: Selecting the top experimental assay...
# 2025-11-07 15:20:36,948 - robin.utils - INFO - Starting comparisons for 105 pairs with max concurrency 100...
# Comparing Hypotheses: 100%|██████████| 105/105 [00:20<00:00,  5.01it/s]
# 2025-11-07 15:20:57,900 - robin.utils - INFO -
# Finished processing pairs.
# 2025-11-07 15:20:57,901 - robin.utils - INFO -  - Successful comparisons: 105
# 2025-11-07 15:20:57,901 - robin.utils - INFO -  - Errors encountered: 0
# 2025-11-07 15:20:57,925 - robin.utils - INFO - Successfully saved 105 results to robin_output/dry_age-related_macular_degeneration_2025-11-07_14-55-20/experimental_assay_ranking_results.csv
# 2025-11-07 15:20:57,942 - robin.assays - INFO - Experimental Assay Selected: Photoreceptor Outer Segment Phagocytosis Assay
# 2025-11-07 15:21:04,111 - robin.assays - INFO - Candidate Generation Goal: Screen and prioritize novel compounds that enhance RPE-mediated photoreceptor outer segment phagocytosis in vitro as candidate therapeutics for dry age-related macular degeneration.

# %% [markdown]
# ### Therapeutic candidate generation

# %%
await therapeutic_candidates(
    candidate_generation_goal=candidate_generation_goal, configuration=config
)
# Out:
# 2025-11-07 16:01:51,624 - robin.candidates - INFO - Starting generation of 55 therapeutic candidates.
# 2025-11-07 16:01:51,624 - robin.candidates - INFO - ———————————————————————————————————————————————————————————————
# 2025-11-07 16:01:51,625 - robin.candidates - INFO -
# Step 1: Formulating relevant queries for literature search...

# %% [markdown]
# # Therapeutic hypothesis generation with experimental data

# %% [markdown]
# ### Running this part of Robin requires access to the Finch data analysis agent, which is currently in a closed beta. Sign up to be a beta tester here: [bit.ly/finchbeta](www.bit.ly/finchbeta). The `robin_full.ipynb notebook` shows an example of the usage of therapeutic hypothesis generation with experimental data.
