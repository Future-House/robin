# %% [markdown]
# # Robin

# %%
import logging

from robin.assays import experimental_assay
from robin.candidates import therapeutic_candidates
from robin.configuration import RobinConfiguration

# %% [markdown]
# ## Robin Set Up

# %%
config = RobinConfiguration(disease_name="dry age-related macular degeneration", num_candidates=50, num_assays=15,num_queries=10)

logger = logging.getLogger("robin")
logger.setLevel(logging.INFO)

# %% [markdown]
# # Initial therapeutics hypothesis generation

# %% [markdown]
# ### Experimental assay generation

# %%
candidate_generation_goal = await experimental_assay(configuration=config)
# Out:
# 2025-11-02 10:18:44,457 - robin.assays - INFO - Starting selection of a relevant experimental assay.
# 2025-11-02 10:18:44,458 - robin.assays - INFO - ————————————————————————————————————————————————————
# 2025-11-02 10:18:44,458 - robin.assays - INFO -
# Step 1: Formulating relevant queries for literature search...
# 2025-11-02 10:18:57,755 - robin.assays - INFO - Generated Queries:
# 2025-11-02 10:18:57,756 - robin.assays - INFO - 1. Search for detailed mechanisms of retinal pigment epithelium (RPE) cell death in dry age-related macular degeneration, including contributions from oxidative stress, mitochondrial dysfunction, lysosomal failure, autophagy impairment, inflammasome activation and complement-mediated cytotoxicity, to inform choice of targets and readouts in cell-based assays
# ...

# %% [markdown]
# ### Therapeutic candidate generation

# %%
await therapeutic_candidates(
    candidate_generation_goal=candidate_generation_goal, configuration=config
)
# Out:
# 2025-10-27 18:11:13,585 - robin.candidates - INFO - Starting generation of 50 therapeutic candidates.
# 2025-10-27 18:11:13,586 - robin.candidates - INFO - ———————————————————————————————————————————————————————————————
# 2025-10-27 18:11:13,587 - robin.candidates - INFO -
# Step 1: Formulating relevant queries for literature search...
# 2025-10-27 18:11:35,693 - robin.candidates - INFO - Generated Queries:
# 2025-10-27 18:11:35,694 - robin.candidates - INFO - 1. High-throughput screening of diverse small-molecule libraries to identify enhancers of human retinal pigment epithelial cell phagocytosis of photoreceptor outer segments in vitro, incorporating phenotypic assay optimization, target engagement confirmation, and mechanistic validation strategies.
# ...

# %% [markdown]
# # Therapeutic hypothesis generation with experimental data

# %% [markdown]
# ### Running this part of Robin requires access to the Finch data analysis agent, which is currently in a closed beta. Sign up to be a beta tester here: [bit.ly/finchbeta](www.bit.ly/finchbeta). The `robin_full.ipynb notebook` shows an example of the usage of therapeutic hypothesis generation with experimental data.
