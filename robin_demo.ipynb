# %% [markdown]
# # Robin

# %%
import logging

from robin.assays import experimental_assay
from robin.candidates import therapeutic_candidates
from robin.configuration import RobinConfiguration

# %% [markdown]
# ## Robin Set Up

# %%
config = RobinConfiguration(
    disease_name="dry age-related macular degeneration",
    llm_name="o4-mini",  # choose between o3-mini, o4-mini, claude-sonnet-4, claude-opus-4, gemini-2.5-flash
    llm_formatter_name="claude-opus-4",
)

logger = logging.getLogger("robin")
logger.setLevel(logging.INFO)

# %% [markdown]
# # Initial therapeutics hypothesis generation

# %% [markdown]
# ### Experimental assay generation

# %%
candidate_generation_goal = await experimental_assay(configuration=config)
# Out:
# 2025-11-23 23:43:04,401 - robin.assays - INFO - Starting selection of a relevant experimental assay.
# 2025-11-23 23:43:04,404 - robin.assays - INFO - ————————————————————————————————————————————————————
# 2025-11-23 23:43:04,408 - robin.assays - INFO -
#
# Step 1: Formulating relevant queries for literature search...
# 2025-11-23 23:43:15,488 - robin.assays - INFO - Generated Queries:
# 2025-11-23 23:43:15,488 - robin.assays - INFO - 1. What are the molecular pathways leading to retinal pigment epithelial cell dysfunction and death in dry age-related macular degeneration, including oxidative stress, complement activation, mitochondrial impairment, lipofuscin accumulation, autophagy dysregulation, and inflammasome activation, and how can we recapitulate these phenotypes in in vitro cell culture models suitable for drug screening?
# 2025-11-23 23:43:15,488 - robin.assays - INFO - 2.  Which established and emerging cell-based assays and readouts, such as high-content imaging, live-cell oxidative stress indicators, complement deposition ELISA, mitochondrial membrane potential assays, autophagic flux reporters, and lipofuscin quantification, have been validated for modeling dry AMD pathology in RPE or photoreceptor cell lines, and what are their dynamic ranges, sensitivity, and suitability for medium-to-high-throughput drug screening?
# 2025-11-23 23:43:15,489 - robin.assays - INFO - 3.  How can in vitro modulation of complement factor H, NLRP3 inflammasome components, or lipid metabolism enzymes in RPE cultures be quantitatively measured using emerging technologies such as biosensors, transcriptomic profiling, or lipidomics, and what are the key positive and negative controls to validate assay specificity and reproducibility for dry AMD drug discovery?
# 2025-11-23 23:43:15,489 - robin.assays - INFO -
#
# Step 2: Conducting literature search with Edison platform...
# 2025-11-23 23:43:16,078 - robin.utils - INFO - Starting literature search for 3 queries using job-futurehouse-paperqa3.
# 2025-11-23 23:55:22,640 - robin.utils - INFO - Finished processing 3 tasks.
# 2025-11-23 23:55:22,647 - robin.utils - INFO - Successfully wrote: query_1_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_literature_reviews/query_1_what.txt
# 2025-11-23 23:55:22,648 - robin.utils - INFO - Successfully wrote: query_2_which.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_literature_reviews/query_2_which.txt
# 2025-11-23 23:55:22,649 - robin.utils - INFO - Successfully wrote: query_3_how.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_literature_reviews/query_3_how.txt
# 2025-11-23 23:55:22,650 - robin.assays - INFO -
#
# Step 3: Generating ideas for relevant experimental assays...
# 2025-11-23 23:55:37,697 - robin.assays - INFO - Strategy: A2E Phototoxicity and Lipofuscin Clearance Assay in iPSC-RPE<|>Reasoning: Differentiate hu...
# 2025-11-23 23:55:37,698 - robin.assays - INFO - Strategy: Complement-Mediated Cytolysis and MAC Deposition Assay in ARPE-19<|>Reasoning: Sensitize A...
# 2025-11-23 23:55:37,698 - robin.assays - INFO - Strategy: Photoreceptor Outer Segment Phagocytosis and Autophagic Flux Assay<|>Reasoning: Feed ARPE-...
# 2025-11-23 23:55:37,705 - robin.assays - INFO - Successfully exported to robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_summary.txt
# 2025-11-23 23:55:37,706 - robin.assays - INFO -
#
# Step 4: Detailed investigation and evaluation for each assay...
# 2025-11-23 23:55:37,707 - robin.utils - INFO - Starting literature search for 3 queries using job-futurehouse-paperqa3.
# 2025-11-24 00:08:22,941 - robin.utils - INFO - Finished processing 3 tasks.
# 2025-11-24 00:08:22,945 - robin.utils - INFO - Successfully wrote: assay_hypothesis_1_a2e.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_detailed_hypotheses/assay_hypothesis_1_a2e.txt
# 2025-11-24 00:08:22,947 - robin.utils - INFO - Successfully wrote: assay_hypothesis_2_complement.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_detailed_hypotheses/assay_hypothesis_2_complement.txt
# 2025-11-24 00:08:22,948 - robin.utils - INFO - Successfully wrote: assay_hypothesis_3_photoreceptor.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_detailed_hypotheses/assay_hypothesis_3_photoreceptor.txt
# 2025-11-24 00:08:22,948 - robin.assays - INFO -
#
# Step 5: Selecting the top experimental assay...
# 2025-11-24 00:08:22,970 - robin.utils - INFO - Starting comparisons for 3 pairs with max concurrency 100...
# Comparing Hypotheses: 100%|██████████| 3/3 [00:12<00:00,  4.14s/it]
# 2025-11-24 00:08:35,412 - robin.utils - INFO -
# Finished processing pairs.
# 2025-11-24 00:08:35,413 - robin.utils - INFO -  - Successful comparisons: 3
# 2025-11-24 00:08:35,413 - robin.utils - INFO -  - Errors encountered: 0
# 2025-11-24 00:08:35,419 - robin.utils - INFO - Successfully saved 3 results to robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/experimental_assay_ranking_results.csv
# 2025-11-24 00:08:35,446 - robin.assays - INFO - Experimental Assay Selected: Complement-Mediated Cytolysis and MAC Deposition Assay in ARPE-19
# 2025-11-24 00:08:39,464 - robin.assays - INFO - Candidate Generation Goal: “Screen a focused small‐molecule library using the Complement‐Mediated Cytolysis and MAC Deposition Assay in ARPE-19 cells to identify and prioritize compounds that inhibit MAC formation and preserve RPE viability as candidate therapies for dry AMD.”

# %% [markdown]
# ### Therapeutic candidate generation

# %%
await therapeutic_candidates(
    candidate_generation_goal=candidate_generation_goal, configuration=config
)
# Out:
# 2025-11-24 00:08:39,482 - robin.candidates - INFO - Starting generation of 5 therapeutic candidates.
# 2025-11-24 00:08:39,483 - robin.candidates - INFO - ———————————————————————————————————————————————————————————————
# 2025-11-24 00:08:39,484 - robin.candidates - INFO -
#
# Step 1: Formulating relevant queries for literature search...
# 2025-11-24 00:08:51,759 - robin.candidates - INFO - Generated Queries:
# 2025-11-24 00:08:51,760 - robin.candidates - INFO - 1. What small molecules or chemical scaffolds have been reported in high‐throughput screens to inhibit membrane attack complex deposition or complement‐mediated cytolysis in ARPE-19 or primary human RPE cells, with evidence of direct target engagement and downstream pathway inhibition?
# 2025-11-24 00:08:51,761 - robin.candidates - INFO - 2.  What preclinical and clinical pharmacokinetic, ocular distribution, and safety data exist for small‐molecule complement inhibitors, particularly those modulating C5b-9 assembly or C5/C6 interaction, including systemic versus intravitreal administration, demonstrating retinal bioavailability and tolerability in animal models or human trials?
# 2025-11-24 00:08:51,761 - robin.candidates - INFO - 3.  What focused small‐molecule libraries or chemical probes have been utilized in complement‐mediated cytolysis assays, and which assay formats, readouts (e.g., MAC deposition ELISA, cell viability assays), and positive control compounds have shown robust, reproducible inhibition of complement activation in ARPE-19 cells?
# 2025-11-24 00:08:51,761 - robin.candidates - INFO - 4.  What genetic, transcriptomic, and functional studies have validated the causative role of complement pathway dysregulation, including CFH, C3, C5 polymorphisms, and alternative pathway activation, in the pathogenesis of dry age-related macular degeneration in patient cohorts or animal models?
# 2025-11-24 00:08:51,762 - robin.candidates - INFO - 5.  What molecular mechanisms link MAC deposition and sublytic complement activation to retinal pigment epithelial cell injury and death in dry AMD, including pathways such as oxidative stress, inflammasome activation, or autophagy dysregulation, in relevant cell and animal models?
# 2025-11-24 00:08:51,768 - robin.candidates - INFO - 6.  What evidence exists from patient‐derived induced pluripotent stem cell–derived RPE or animal models demonstrating that inhibition of MAC formation preserves retinal structure and function, with mechanistic confirmation of target engagement and pathway modulation in vivo or ex vivo?
# 2025-11-24 00:08:51,769 - robin.candidates - INFO -
#
# Step 2: Conducting literature search with Edison platform...
# 2025-11-24 00:08:51,770 - robin.utils - INFO - Starting literature search for 6 queries using job-futurehouse-paperqa3.
# 2025-11-24 00:22:02,926 - robin.utils - INFO - Finished processing 6 tasks.
# 2025-11-24 00:22:02,929 - robin.utils - INFO - Successfully wrote: query_1_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_1_what.txt
# 2025-11-24 00:22:02,930 - robin.utils - INFO - Successfully wrote: query_2_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_2_what.txt
# 2025-11-24 00:22:02,932 - robin.utils - INFO - Successfully wrote: query_3_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_3_what.txt
# 2025-11-24 00:22:02,932 - robin.utils - INFO - Successfully wrote: query_4_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_4_what.txt
# 2025-11-24 00:22:02,934 - robin.utils - INFO - Successfully wrote: query_5_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_5_what.txt
# 2025-11-24 00:22:02,935 - robin.utils - INFO - Successfully wrote: query_6_what.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_literature_reviews/query_6_what.txt
# 2025-11-24 00:22:02,935 - robin.candidates - INFO -
#
# Step 3: Generating 5 ideas for therapeutic candidates...
# 2025-11-24 00:22:37,139 - robin.candidates - INFO -
# Successfully parsed 5 candidate ideas.
# 2025-11-24 00:22:37,140 - robin.candidates - INFO - Candidate: Avacopan<|>Hypothesis: Avacopan, a potent oral antagonist of the C5a receptor 1 (C5aR1), ...
# 2025-11-24 00:22:37,141 - robin.candidates - INFO - Candidate: Iptacopan<|>Hypothesis: Iptacopan, a selective small-molecule inhibitor of complement fac...
# 2025-11-24 00:22:37,141 - robin.candidates - INFO - Candidate: MCC950<|>Hypothesis: MCC950, a selective inhibitor of the NLRP3 inflammasome, will preven...
# 2025-11-24 00:22:37,141 - robin.candidates - INFO - Candidate: Desipramine<|>Hypothesis: Desipramine, a functional inhibitor of acid sphingomyelinase (F...
# 2025-11-24 00:22:37,142 - robin.candidates - INFO - Candidate: A-438079<|>Hypothesis: A-438079, a selective antagonist of the P2X7 receptor, will inhibi...
# 2025-11-24 00:22:37,150 - robin.candidates - INFO - Successfully exported to robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidates_summary.txt
# 2025-11-24 00:22:37,150 - robin.candidates - INFO -
#
# Step 4: Detailed investigation and evaluation for candidates...
# 2025-11-24 00:22:37,151 - robin.utils - INFO - Starting literature search for 5 queries using job-futurehouse-paperqa3.
# 2025-11-24 00:35:13,332 - robin.utils - INFO - Finished processing 5 tasks.
# {'results': [{'hypothesis': 'Avacopan', 'query': 'You are a expert drug development team leader focused on validating **drug candidates**. Your task is to evaluate promising repurposed drugs or therapeutic candidates for dry age-related macular degeneration proposed by your research team. \nGiven the following therapeutic candidate, do a comprehensive literature review to evaluate if this therapeutic candidate has potential for dry age-related macular degeneration. Search relevant literature across \nbiomedical, clinical, and biochemical literature about the disease or proposed therapeutic. This must be very detailed and comprehensive, as it will determine the direction of the team.Candidate: Avacopan\nHypothesis: Avacopan, a potent oral antagonist of the C5a receptor 1 (C5aR1), will block C5a-mediated inflammatory signaling in retinal pigment epithelial cells, preventing sublytic complement activation–driven NLRP3 inflammasome assembly and downstream cytokine release, thereby preserving RPE barrier integrity and viability in dry age-related macular degeneration.\nReasoning: Genetic and biomarker studies in dry AMD patients show elevated C5a levels and up-regulation of C5aR1 in RPE/choriocapillaris, implicating C5a-C5aR1 signaling in inflammasome activation and proinflammatory cytokine release (IL-1β, IL-18). In vitro, C5a induces Ca²⁺ influx and NLRP3 activation in ARPE-19 cells, driving barrier loss and cell death. Avacopan (CCX168) is an orally bioavailable small molecule with established safety in ANCA-associated vasculitis, demonstrating tissue distribution in inflammatory models. Its mechanistic specificity for C5aR1 blocks both anaphylatoxin signaling and amplification loops that feed into MAC deposition and sublytic injury. Developmental feasibility is high given its advanced clinical status and favorable PK, and repurposing for dry AMD offers a novel approach distinct from C3/C5 direct inhibitors previously tested.Provide your response in the following format, like an evaluation for a scientific proposal:\nOverview of Therapeutic Candidate: Explain the natural or synthetic origins of this therapeutic candidate, including how it was synthesized or discovered. Explain which class of therapeutic compounds this belongs to, and how this class of compounds has previously been used in general. \nTherapeutic History: Summarize previous biochemical, clinical or veterinary uses of this drug or drug class, if any. Examine to see if the therapeutic candidate has ever been used for treating dry age-related macular degeneration or any similar disease.\nMechanism of Action: Explain the known mechanism(s) of action of this compound to the full extent of molecular detail that is known. Explain the biochemistry and molecular interactions of the therapeutic candidate in any relevant literature.\nExpected Effect: Explain the expected effect of this compound in the assay proposed and the mechanism by which it will act. If the drug is acting on proteins, reference literature which shows this gene is expressed in the cell type being assayed.  \nOverall Evaluation: Give your overall thoughts on this therapeutic candidate. Include strengths and weaknesses of this therapeutic candidate for treating dry age-related macular degeneration.', 'answer': 'Plan status: Objectives 1–7 completed; final synthesis below.\n\nOverview of Therapeutic Candidate\nAvacopan (CCX168) is a synthetic, orally bioavailable small‑molecule antagonist of the human C5a receptor 1 (C5aR1). It was discovered through medicinal chemistry campaigns to selectively block signaling of the complement anaphylatoxin C5a without inhibiting C5b‑9/MAC formation. As a C5aR1 antagonist, avacopan belongs to the class of complement‑targeted GPCR inhibitors; this class has been deployed clinically to modulate inflammatory cascades driven by C5a in systemic diseases, notably ANCA‑associated vasculitis, with established human PK and safety. Class reviews emphasize the advantage of selectivel ...
# 2025-11-24 00:37:41,042 - robin.utils - INFO - Successfully wrote: therapeutic_candidate_1_avacopan.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_detailed_hypotheses/therapeutic_candidate_1_avacopan.txt
# 2025-11-24 00:37:41,043 - robin.utils - INFO - Successfully wrote: therapeutic_candidate_2_iptacopan.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_detailed_hypotheses/therapeutic_candidate_2_iptacopan.txt
# 2025-11-24 00:37:41,045 - robin.utils - INFO - Successfully wrote: therapeutic_candidate_3_mcc950.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_detailed_hypotheses/therapeutic_candidate_3_mcc950.txt
# 2025-11-24 00:37:41,046 - robin.utils - INFO - Successfully wrote: therapeutic_candidate_4_desipramine.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_detailed_hypotheses/therapeutic_candidate_4_desipramine.txt
# 2025-11-24 00:37:41,048 - robin.utils - INFO - Successfully wrote: therapeutic_candidate_5_a.txt to: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_detailed_hypotheses/therapeutic_candidate_5_a.txt
# 2025-11-24 00:37:41,049 - robin.candidates - INFO -
#
# Step 5: Ranking the strength of the therapeutic candidates...
# 2025-11-24 00:37:41,050 - robin.utils - INFO - Processing file: therapeutic_candidate_4_desipramine.txt...
# 2025-11-24 00:37:41,052 - robin.utils - INFO - Processing file: therapeutic_candidate_1_avacopan.txt...
# 2025-11-24 00:37:41,053 - robin.utils - INFO - Processing file: therapeutic_candidate_5_a.txt...
# 2025-11-24 00:37:41,054 - robin.utils - INFO - Processing file: therapeutic_candidate_2_iptacopan.txt...
# 2025-11-24 00:37:41,054 - robin.utils - INFO - Processing file: therapeutic_candidate_3_mcc950.txt...
# 2025-11-24 00:37:41,059 - robin.utils - INFO - Starting comparisons for 10 pairs with max concurrency 100...
# Comparing Hypotheses: 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]
# 2025-11-24 00:37:54,919 - robin.utils - INFO -
# Finished processing pairs.
# 2025-11-24 00:37:54,919 - robin.utils - INFO -  - Successful comparisons: 10
# 2025-11-24 00:37:54,919 - robin.utils - INFO -  - Errors encountered: 0
# 2025-11-24 00:37:54,933 - robin.utils - INFO - Successfully saved 10 results to robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_ranking_results.csv
# 2025-11-24 00:37:54,934 - robin.candidates - INFO - Processing ranking output from: robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/therapeutic_candidate_ranking_results.csv
# 2025-11-24 00:37:54,945 - robin.candidates - INFO - Calling choix.ilsr_pairwise with n_items=5 and 10 games.
# 2025-11-24 00:37:54,958 - robin.candidates - INFO - Finished! Saved final rankings to robin_output/dry_age-related_macular_degeneration_2025-11-23_23-43-04/ranked_therapeutic_candidates.csv

# %% [markdown]
# # Therapeutic hypothesis generation with experimental data

# %% [markdown]
# ### Running this part of Robin requires access to the Finch data analysis agent, which is currently in a closed beta. Sign up to be a beta tester here: [bit.ly/finchbeta](www.bit.ly/finchbeta). The `robin_full.ipynb notebook` shows an example of the usage of therapeutic hypothesis generation with experimental data.
